# %% [markdown]
# `1` Takes (pickup signals, coil currents, p-profile) --> poloidal flux map --> Classification of limiter or diverted and identification of LCFS

# %%
# !hostname
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('CPU')))
# Out:
# dhcp-10-29-202-58.dyn.MIT.EDU
# Num GPUs Available:  1

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"]="1"   
import random

import numpy as np
import pandas as pd
from numpy import matlib as mb
import matplotlib.pyplot as plt
import scipy.io

import seaborn as sns
sns.set_style("darkgrid")

import random
import matplotlib.lines as mlines

import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras.layers import Dense, Activation, Dropout
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

print("TensorFlow version: ", tf.__version__)

from sklearn.model_selection import KFold, train_test_split
from sklearn.model_selection import cross_val_score, KFold, cross_val_predict
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.base import TransformerMixin
from sklearn.metrics import (r2_score, f1_score, accuracy_score, 
                             roc_curve, roc_auc_score, mean_squared_error)

import scipy.interpolate as interp
from scipy import interpolate, signal
import scipy.ndimage
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
#import mat73
# Out:
# TensorFlow version:  2.18.0

# %%
filename='/Users/aprilren/Downloads/UROP/ITER_like_equilibrium_dataset.mat'
mat = scipy.io.loadmat(filename)
...
for key,val in mat.items():
    print(key)
    exec(key + '=val')
# Out:
# __header__
# __version__
# __globals__
# DB_meas_Bpickup_test_ConvNet
# DB_psi_pixel_test_ConvNet
# DB_res_RHS_pixel_test_ConvNet
# DB_Jpla_pixel_test_ConvNet
# DB_coils_curr_test_ConvNet
# RR_pixels
# ZZ_pixels
# DB_separatrix_200_test_ConvNet
# XP_YN
# DB_f_test_ConvNet
# DB_p_test_ConvNet

# %%
DTYPE = 'float32'

DB_meas_Bpickup_test_ConvNet = mat['DB_meas_Bpickup_test_ConvNet'].astype(DTYPE)
DB_coils_curr_test_ConvNet   = mat['DB_coils_curr_test_ConvNet'].astype(DTYPE)
DB_p_test_ConvNet            = mat['DB_p_test_ConvNet'].astype(DTYPE)
res_RHS_pixel_data_load      = mat['DB_res_RHS_pixel_test_ConvNet'].astype(DTYPE)

RR_pixels                    = mat['RR_pixels'].astype(DTYPE)
ZZ_pixels                    = mat['ZZ_pixels'].astype(DTYPE)

DB_res_RHS_pixel_test_ConvNet   = mat['DB_res_RHS_pixel_test_ConvNet'].astype(DTYPE)
DB_separatrix_200_test_ConvNet  = mat['DB_separatrix_200_test_ConvNet'].astype(DTYPE)
XP_YN                           = mat["XP_YN"]                    # optional (diverted vs limiter)

DB_psi_pixel_test_ConvNet    = mat['DB_psi_pixel_test_ConvNet'].astype(DTYPE)
DB_Jpla_pixel_test_ConvNet   = mat['DB_Jpla_pixel_test_ConvNet'].astype(DTYPE)

print("DB_meas_Bpickup_test_ConvNet shape:", DB_meas_Bpickup_test_ConvNet.shape)
print("DB_coils_curr_test_ConvNet shape:   ", DB_coils_curr_test_ConvNet.shape)
print("DB_p_test_ConvNet shape:            ", DB_p_test_ConvNet.shape)
print("DB_psi_pixel_test_ConvNet shape:    ", DB_psi_pixel_test_ConvNet.shape)
print("RR_pixels shape:                    ", RR_pixels.shape)
print("ZZ_pixels shape:                    ", ZZ_pixels.shape)
print("XP_YN shape:                        ", XP_YN.shape)
print("DB_separatrix_200_test_ConvNet shape:", DB_separatrix_200_test_ConvNet.shape)
print("res_RHS_pixel_data_load shape:      ", res_RHS_pixel_data_load.shape)
# Out:
# DB_meas_Bpickup_test_ConvNet shape: (81986, 187)
# DB_coils_curr_test_ConvNet shape:    (81986, 14)
# DB_p_test_ConvNet shape:             (81986, 101)
# DB_psi_pixel_test_ConvNet shape:     (81986, 64, 64)
# RR_pixels shape:                     (64, 64)
# ZZ_pixels shape:                     (64, 64)
# XP_YN shape:                         (1, 81986)
# DB_separatrix_200_test_ConvNet shape: (81986, 200, 2)
# res_RHS_pixel_data_load shape:       (81986, 64, 64)

# %%
plt.figure(figsize=(9, 5))
ind_plot = np.random.randint(0,DB_Jpla_pixel_test_ConvNet.shape[0],1)[0]
print(ind_plot)
for i in range(1,1000):
    plt.plot(DB_separatrix_200_test_ConvNet[i,:,0],DB_separatrix_200_test_ConvNet[i,:,1])
    plt.axis('equal')
plt.show()
# Out:
# 25728

# %%
for i in range(0,1):
    ind_plot = np.random.randint(0,DB_Jpla_pixel_test_ConvNet.shape[0],1)[0]
    fig, axs = plt.subplots(1, 2, figsize=(9, 5), sharey=True)
    img = axs[0].contour(RR_pixels,ZZ_pixels,DB_psi_pixel_test_ConvNet[ind_plot,:,:],15)
    fig.colorbar(img)
    axs[0].plot(
        DB_separatrix_200_test_ConvNet[ind_plot,:,0],
        DB_separatrix_200_test_ConvNet[ind_plot,:,1],
        c='g')
    axs[0].axis('equal')
    axs[0].set_xlabel('r [m]')
    axs[0].set_ylabel('z [m]')
    axs[0].set_title('$\Psi$ [Wb] - equil. #{}'.format(ind_plot))
    img = axs[1].contourf(RR_pixels,ZZ_pixels,DB_Jpla_pixel_test_ConvNet[ind_plot,:,:],15)
    fig.colorbar(img)
    axs[1].axis('equal')
    axs[1].set_title('$J_\phi$ [A/m2] - equil. #{}'.format(ind_plot))
    axs[1].set_xlabel('r [m]')
    axs[1].set_ylabel('z [m]')
    axs[1].plot(
        DB_separatrix_200_test_ConvNet[ind_plot,:,0],
        DB_separatrix_200_test_ConvNet[ind_plot,:,1],
        c='g')

# %%
#[B_pickup signals, coil currents, p-profile]
X_data = np.column_stack([
    DB_meas_Bpickup_test_ConvNet,
    DB_coils_curr_test_ConvNet,
    DB_p_test_ConvNet
])

# The target: 2D poloidal flux map for each sample
y_data = DB_psi_pixel_test_ConvNet  # shape: (num_samples, nR, nZ)

# %%
num_samples = X_data.shape[0]
indices = np.arange(num_samples)

id_train, id_test = train_test_split(indices, test_size=0.3, random_state=42)

X_train = X_data[id_train, :]
X_test  = X_data[id_test, :]

y_train = y_data[id_train, :, :]
y_test  = y_data[id_test, :, :]

# %%
def apply_laplacian(psi):
    """
    Applies a 2D Laplacian to each (nR, nZ) flux map using TensorFlow to compute ∆ψ
    Input shape: (batch, nR, nZ)
    Output shape: (batch, nR, nZ)
    """
    psi = tf.convert_to_tensor(psi, dtype=tf.float32)
    # y shape: (num_samples, nR, nZ)
    psi = tf.expand_dims(psi, axis=-1) # reshape because so output is (batch, nR, nZ, 1)

    # 2D convolution discrete version of Laplacian kernel sourced from online:
    laplacian_kernel = tf.constant([
        [0.,  1., 0.],
        [1., -4., 1.],
        [0.,  1., 0.]
    ], dtype=tf.float32)
    laplacian_kernel = tf.reshape(laplacian_kernel, [3, 3, 1, 1])

    # convolution
    delta_psi = tf.nn.conv2d(psi, laplacian_kernel, strides=[1, 1, 1, 1], padding='SAME')

    # remove the last dimension to return to original shape
    return tf.squeeze(delta_psi, axis=-1)

def loss_function_29(y, y_pred):
    """
    Computes eq. 29: L^*_Δ(ψ, ψ^p) = (1/M) * Σ (Δ*ψ - Δ*ψ^p)^2
    """
    delta_psi = apply_laplacian(y)
    delta_psi_pred = apply_laplacian(y_pred)
    return tf.reduce_mean(tf.square(delta_psi - delta_psi_pred))

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
n_r = y_train.shape[1]  # number of radial points
n_z = y_train.shape[2]  # number of vertical points
out_size = n_r * n_z    # flatten the 2D flux map

def build_dense_model(input_dim, output_dim):
    inputs = keras.Input(shape=(input_dim,))
    x = layers.Dense(128, activation='relu')(inputs)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(output_dim, activation='linear')(x) # added dense layer to output flat vector
    outputs = layers.Reshape((n_r, n_z))(x) # reshaped output layer
    # outputs = layers.Dense(output_dim, activation='linear')(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss=loss_function_29)
    return model

model = build_dense_model(input_dim=X_train.shape[1], output_dim=out_size)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 302)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │        38,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 4096)           │       528,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 64, 64)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 600,192 (2.29 MB)
#  Trainable params: 600,192 (2.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# y_train_flat = y_train.reshape(y_train.shape[0], -1)  # shape: (N, nR*nZ)
# y_test_flat  = y_test.reshape(y_test.shape[0], -1)

# history = model.fit(X_train, y_train_flat,
                    # validation_data=(X_test, y_test_flat),
                    # epochs=50, batch_size=32, verbose=1)

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.4390 - val_loss: 0.0232
# Epoch 2/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0181 - val_loss: 0.0090
# Epoch 3/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 0.0156 - val_loss: 0.0117
# Epoch 4/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 5/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 0.0110 - val_loss: 0.0048
# Epoch 6/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 7/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - loss: 0.0066 - val_loss: 0.0043
# Epoch 8/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - loss: 0.0056 - val_loss: 0.0097
# Epoch 9/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 10/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0051 - val_loss: 0.0083
# Epoch 11/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 12/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0036 - val_loss: 0.0072
# Epoch 13/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 14/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 15/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 16/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0032 - val_loss: 0.0071
# Epoch 17/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 18/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 19/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 20/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 21/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0025 - val_loss: 0.0081
# Epoch 22/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 23/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 24/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 25/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 26/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 27/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 28/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 29/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 30/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 31/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 32/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0023 - val_loss: 9.6015e-04
# Epoch 33/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 34/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 35/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 36/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 38/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 39/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 40/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 41/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 42/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 43/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0015 - val_loss: 9.3581e-04
# Epoch 44/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 45/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0016 - val_loss: 8.6250e-04
# Epoch 46/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 0.0015 - val_loss: 9.9601e-04
# Epoch 47/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 48/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0018 - val_loss: 9.3251e-04
# Epoch 49/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0014 - val_loss: 7.0709e-04
# Epoch 50/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0013 - val_loss: 0.0018

# %%
y_pred_train_flat = model.predict(X_train)
y_pred_test_flat  = model.predict(X_test)

y_pred_train = y_pred_train_flat.reshape(-1, n_r, n_z)# Reshape back to 2D flux
y_pred_test  = y_pred_test_flat.reshape(-1, n_r, n_z)
# Out:
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 1s 551us/step
# 769/769 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step

# %%
y_train_flat = y_train.reshape(y_train.shape[0], -1)  # shape: (N, nR*nZ)
y_test_flat  = y_test.reshape(y_test.shape[0], -1)

r2_train = r2_score(y_train_flat, y_pred_train_flat)
r2_test  = r2_score(y_test_flat,  y_pred_test_flat)
mse_train = mean_squared_error(y_train_flat, y_pred_train_flat)
mse_test  = mean_squared_error(y_test_flat,  y_pred_test_flat)

print(f"R² train={r2_train:.4f}, test={r2_test:.4f}")
print(f"MSE train={mse_train:.6e}, test={mse_test:.6e}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       1 y_train_flat = y_train.reshape(y_train.shape[0], -1)  # shape: (N, nR*nZ)
#       2 y_test_flat  = y_test.reshape(y_test.shape[0], -1)
# ----> 4 r2_train = r2_score(y_train_flat, y_pred_train_flat)
#       5 r2_test  = r2_score(y_test_flat,  y_pred_test_flat)
#       6 mse_train = mean_squared_error(y_train_flat, y_pred_train_flat)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:1257, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1133 """:math:`R^2` (coefficient of determination) regression score function.
#    1134
#    1135 Best possible score is 1.0 and it can be negative (because the
#    (...)   1250 -inf
#    1251 """
#    1252 xp, _, device_ = get_namespace_and_device(
#    1253     y_true, y_pred, sample_weight, multioutput
#    1254 )
#    1256 _, y_true, y_pred, sample_weight, multioutput = (
# -> 1257     _check_reg_targets_with_floating_dtype(
#    1258         y_true, y_pred, sample_weight, multioutput, xp=xp
#    1259     )
#    1260 )
#    1262 check_consistent_length(y_true, y_pred, sample_weight)
#    1264 if _num_samples(y_pred) < 2:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:198, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     148 """Ensures that y_true, y_pred, and sample_weight correspond to the same
#     149 regression task.
#     150
#    (...)    194     correct keyword.
#     195 """
#     196 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 198 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     199     y_true, y_pred, multioutput, dtype=dtype_name, xp=xp
#     200 )
#     202 # _check_reg_targets does not accept sample_weight as input.
#     203 # Convert sample_weight's data type separately to match dtype_name.
#     204 if sample_weight is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:106, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#     104 check_consistent_length(y_true, y_pred)
#     105 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 106 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     108 if y_true.ndim == 1:
#     109     y_true = xp.reshape(y_true, (-1, 1))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1101, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1096     raise ValueError(
#    1097         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1098         "Convert your data to numeric values explicitly instead."
#    1099     )
#    1100 if not allow_nd and array.ndim >= 3:
# -> 1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
#    1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#
# ValueError: Found array with dim 3. None expected <= 2.

# %%
import random
idx = random.randint(0, len(id_test)-1)

psi_ref = y_test[idx,:,:]
psi_pred = y_pred_test[idx,:,:]

plt.figure(figsize=(12,8))
#plt.suptitle(f"Sample index {idx} (Test)")
plt.subplot(1,2,1)
plt.title("$\psi_{Ref}$")
plt.contourf(RR_pixels, ZZ_pixels, psi_ref, 30)
plt.colorbar()
plt.axis('equal')
plt.subplot(1,2,2)
plt.title("$\psi_{pred}$")
plt.contourf(RR_pixels, ZZ_pixels, psi_pred, 30)
plt.colorbar()
plt.axis('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import random
# ----> 2 idx = random.randint(0, len(id_test)-1)
#       4 psi_ref = y_test[idx,:,:]
#       5 psi_pred = y_pred_test[idx,:,:]
#
# NameError: name 'id_test' is not defined

# %%
N, nR, nZ = DB_psi_pixel_test_ConvNet.shape
flux_flat = DB_psi_pixel_test_ConvNet.reshape(N, -1)  # shape: (N, nR*nZ)
XP_YN.shape
# Out:
# (1, 81986)

# %%
y_class = XP_YN.squeeze().astype(np.float32)  # shape: (N,)
y_class.shape
# Out:
# (81986,)

# %%
N_bound_pts = DB_separatrix_200_test_ConvNet.shape[1]  # 200
y_boundary = DB_separatrix_200_test_ConvNet.reshape(N, -1).astype(np.float32)  # shape: (N, 400)

yindices = np.arange(N)
id_train, id_test = train_test_split(yindices, test_size=0.3, random_state=42)
id_test.shape
# Out:
# (24596,)

# %%
X_train = flux_flat[id_train, :]  # shape: (N_train, nR*nZ)
X_test  = flux_flat[id_test, :]
y_class_train = y_class[id_train]         # shape: (N_train,)
y_class_test  = y_class[id_test]
y_bound_train = y_boundary[id_train, :]   # shape: (N_train, 400)
y_bound_test  = y_boundary[id_test, :]
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
def build_multi_output_model(n_input, n_boundary):
    """
    n_input: size of flattened flux (nR*nZ)
    n_boundary: total boundary coords to predict (200*2 = 400)
    """
    inputs = layers.Input(shape=(n_input,))
    x = layers.Dense(128, activation='relu')(inputs)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(64, activation='relu')(x)
    clas_out = layers.Dense(1, activation='sigmoid', name="classification_head")(x)
    bound_out = layers.Dense(n_boundary, activation='linear', name="boundary_head")(x)
    model = Model(inputs=inputs, outputs=[clas_out, bound_out])
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss={
            "classification_head": "binary_crossentropy",
            "boundary_head": "mse"
        },
        metrics={
            "classification_head": ["accuracy"]
        }
    )

    return model
n_input = X_train_scaled.shape[1]  # nR*nZ
n_boundary = y_bound_train.shape[1]  # 400
model_multi = build_multi_output_model(n_input, n_boundary)
model_multi.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 4096)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │    524,416 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     16,512 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      8,256 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification_head │ (None, 1)         │         65 │ dense_6[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ boundary_head       │ (None, 400)       │     26,000 │ dense_6[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 575,249 (2.19 MB)
#  Trainable params: 575,249 (2.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Defining Loss Function
# * Loss= $\alpha_{1} \|\psi_{pred} − \psi_{ref}\|^{2} + \alpha_{2} \|\Delta^{*}\psi_{pred} − \Delta^{*}\psi_{ref}\|^2$

# %%
history_cl = model_multi.fit(
    X_train_scaled,
    [y_class_train, y_bound_train],
    validation_data=(
        X_test_scaled,
        [y_class_test, y_bound_test]
    ),
    epochs=50,
    batch_size=32,
    verbose=1
)
y_class_pred_train, y_bound_pred_train = model_multi.predict(X_train_scaled)
y_class_pred_test,  y_bound_pred_test  = model_multi.predict(X_test_scaled)
y_class_bin_train = (y_class_pred_train > 0.5).astype(int).ravel()
y_class_bin_test  = (y_class_pred_test  > 0.5).astype(int).ravel()
acc_train = accuracy_score(y_class_train, y_class_bin_train)
acc_test  = accuracy_score(y_class_test,  y_class_bin_test)

f1_train  = f1_score(y_class_train, y_class_bin_train)
f1_test   = f1_score(y_class_test,  y_class_bin_test)

print(f"Classification - TRAIN: Acc={acc_train:.3f}, F1={f1_train:.3f}")
print(f"Classification - TEST:  Acc={acc_test:.3f},  F1={f1_test:.3f}")
# Out:
# Epoch 1/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - boundary_head_loss: 2.6305 - classification_head_accuracy: 0.8850 - classification_head_loss: 0.2809 - loss: 2.9114 - val_boundary_head_loss: 0.4312 - val_classification_head_accuracy: 0.9637 - val_classification_head_loss: 0.0858 - val_loss: 0.5170
# Epoch 2/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.4569 - classification_head_accuracy: 0.9587 - classification_head_loss: 0.1034 - loss: 0.5603 - val_boundary_head_loss: 0.2402 - val_classification_head_accuracy: 0.9820 - val_classification_head_loss: 0.0496 - val_loss: 0.2899
# Epoch 3/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - boundary_head_loss: 0.2805 - classification_head_accuracy: 0.9708 - classification_head_loss: 0.0735 - loss: 0.3540 - val_boundary_head_loss: 0.2540 - val_classification_head_accuracy: 0.9731 - val_classification_head_loss: 0.0779 - val_loss: 0.3319
# Epoch 4/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.2361 - classification_head_accuracy: 0.9718 - classification_head_loss: 0.0739 - loss: 0.3100 - val_boundary_head_loss: 0.1591 - val_classification_head_accuracy: 0.9728 - val_classification_head_loss: 0.0668 - val_loss: 0.2260
# Epoch 5/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.1938 - classification_head_accuracy: 0.9731 - classification_head_loss: 0.0703 - loss: 0.2641 - val_boundary_head_loss: 0.1728 - val_classification_head_accuracy: 0.9658 - val_classification_head_loss: 0.0807 - val_loss: 0.2536
# Epoch 6/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - boundary_head_loss: 0.1477 - classification_head_accuracy: 0.9773 - classification_head_loss: 0.0602 - loss: 0.2079 - val_boundary_head_loss: 0.1235 - val_classification_head_accuracy: 0.9798 - val_classification_head_loss: 0.0503 - val_loss: 0.1739
# Epoch 7/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.1363 - classification_head_accuracy: 0.9770 - classification_head_loss: 0.0578 - loss: 0.1942 - val_boundary_head_loss: 0.0932 - val_classification_head_accuracy: 0.9880 - val_classification_head_loss: 0.0337 - val_loss: 0.1269
# Epoch 8/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.1383 - classification_head_accuracy: 0.9762 - classification_head_loss: 0.0617 - loss: 0.2000 - val_boundary_head_loss: 0.0982 - val_classification_head_accuracy: 0.9780 - val_classification_head_loss: 0.0514 - val_loss: 0.1496
# Epoch 9/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - boundary_head_loss: 0.1093 - classification_head_accuracy: 0.9805 - classification_head_loss: 0.0512 - loss: 0.1604 - val_boundary_head_loss: 0.1345 - val_classification_head_accuracy: 0.9821 - val_classification_head_loss: 0.0436 - val_loss: 0.1781
# Epoch 10/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.1143 - classification_head_accuracy: 0.9787 - classification_head_loss: 0.0543 - loss: 0.1687 - val_boundary_head_loss: 0.1779 - val_classification_head_accuracy: 0.9617 - val_classification_head_loss: 0.1009 - val_loss: 0.2790
# Epoch 11/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - boundary_head_loss: 0.1046 - classification_head_accuracy: 0.9783 - classification_head_loss: 0.0550 - loss: 0.1596 - val_boundary_head_loss: 0.1702 - val_classification_head_accuracy: 0.9618 - val_classification_head_loss: 0.1073 - val_loss: 0.2776
# Epoch 12/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - boundary_head_loss: 0.0929 - classification_head_accuracy: 0.9804 - classification_head_loss: 0.0509 - loss: 0.1438 - val_boundary_head_loss: 0.0777 - val_classification_head_accuracy: 0.9836 - val_classification_head_loss: 0.0422 - val_loss: 0.1200
# Epoch 13/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0867 - classification_head_accuracy: 0.9817 - classification_head_loss: 0.0465 - loss: 0.1332 - val_boundary_head_loss: 0.1920 - val_classification_head_accuracy: 0.9576 - val_classification_head_loss: 0.1484 - val_loss: 0.3405
# Epoch 14/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0871 - classification_head_accuracy: 0.9807 - classification_head_loss: 0.0507 - loss: 0.1379 - val_boundary_head_loss: 0.1270 - val_classification_head_accuracy: 0.9766 - val_classification_head_loss: 0.0499 - val_loss: 0.1770
# Epoch 15/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 59s 33ms/step - boundary_head_loss: 0.0874 - classification_head_accuracy: 0.9828 - classification_head_loss: 0.0432 - loss: 0.1305 - val_boundary_head_loss: 0.1123 - val_classification_head_accuracy: 0.9773 - val_classification_head_loss: 0.0633 - val_loss: 0.1756
# Epoch 16/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - boundary_head_loss: 0.0878 - classification_head_accuracy: 0.9802 - classification_head_loss: 0.0501 - loss: 0.1379 - val_boundary_head_loss: 0.0675 - val_classification_head_accuracy: 0.9816 - val_classification_head_loss: 0.0394 - val_loss: 0.1069
# Epoch 17/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0835 - classification_head_accuracy: 0.9821 - classification_head_loss: 0.0485 - loss: 0.1320 - val_boundary_head_loss: 0.1750 - val_classification_head_accuracy: 0.9844 - val_classification_head_loss: 0.0506 - val_loss: 0.2256
# Epoch 18/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - boundary_head_loss: 0.1178 - classification_head_accuracy: 0.9795 - classification_head_loss: 0.0557 - loss: 0.1735 - val_boundary_head_loss: 0.1526 - val_classification_head_accuracy: 0.9641 - val_classification_head_loss: 0.1056 - val_loss: 0.2581
# Epoch 19/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0827 - classification_head_accuracy: 0.9825 - classification_head_loss: 0.0453 - loss: 0.1280 - val_boundary_head_loss: 0.0502 - val_classification_head_accuracy: 0.9882 - val_classification_head_loss: 0.0312 - val_loss: 0.0814
# Epoch 20/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - boundary_head_loss: 0.0680 - classification_head_accuracy: 0.9857 - classification_head_loss: 0.0386 - loss: 0.1065 - val_boundary_head_loss: 0.0499 - val_classification_head_accuracy: 0.9903 - val_classification_head_loss: 0.0289 - val_loss: 0.0787
# Epoch 21/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0649 - classification_head_accuracy: 0.9865 - classification_head_loss: 0.0359 - loss: 0.1008 - val_boundary_head_loss: 0.0702 - val_classification_head_accuracy: 0.9858 - val_classification_head_loss: 0.0375 - val_loss: 0.1077
# Epoch 22/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0775 - classification_head_accuracy: 0.9837 - classification_head_loss: 0.0422 - loss: 0.1197 - val_boundary_head_loss: 0.0669 - val_classification_head_accuracy: 0.9859 - val_classification_head_loss: 0.0375 - val_loss: 0.1044
# Epoch 23/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0732 - classification_head_accuracy: 0.9837 - classification_head_loss: 0.0437 - loss: 0.1169 - val_boundary_head_loss: 0.0513 - val_classification_head_accuracy: 0.9885 - val_classification_head_loss: 0.0314 - val_loss: 0.0827
# Epoch 24/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0695 - classification_head_accuracy: 0.9841 - classification_head_loss: 0.0452 - loss: 0.1147 - val_boundary_head_loss: 0.0642 - val_classification_head_accuracy: 0.9874 - val_classification_head_loss: 0.0335 - val_loss: 0.0977
# Epoch 25/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0696 - classification_head_accuracy: 0.9844 - classification_head_loss: 0.0386 - loss: 0.1082 - val_boundary_head_loss: 0.0570 - val_classification_head_accuracy: 0.9841 - val_classification_head_loss: 0.0359 - val_loss: 0.0929
# Epoch 26/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0930 - classification_head_accuracy: 0.9822 - classification_head_loss: 0.0520 - loss: 0.1450 - val_boundary_head_loss: 0.1269 - val_classification_head_accuracy: 0.9709 - val_classification_head_loss: 0.0795 - val_loss: 0.2064
# Epoch 27/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0684 - classification_head_accuracy: 0.9851 - classification_head_loss: 0.0395 - loss: 0.1078 - val_boundary_head_loss: 0.0532 - val_classification_head_accuracy: 0.9843 - val_classification_head_loss: 0.0356 - val_loss: 0.0889
# Epoch 28/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0633 - classification_head_accuracy: 0.9860 - classification_head_loss: 0.0370 - loss: 0.1003 - val_boundary_head_loss: 0.0453 - val_classification_head_accuracy: 0.9894 - val_classification_head_loss: 0.0262 - val_loss: 0.0715
# Epoch 29/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0614 - classification_head_accuracy: 0.9864 - classification_head_loss: 0.0349 - loss: 0.0963 - val_boundary_head_loss: 0.0546 - val_classification_head_accuracy: 0.9900 - val_classification_head_loss: 0.0304 - val_loss: 0.0850
# Epoch 30/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0641 - classification_head_accuracy: 0.9850 - classification_head_loss: 0.0376 - loss: 0.1017 - val_boundary_head_loss: 0.0699 - val_classification_head_accuracy: 0.9889 - val_classification_head_loss: 0.0281 - val_loss: 0.0980
# Epoch 31/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0582 - classification_head_accuracy: 0.9873 - classification_head_loss: 0.0341 - loss: 0.0922 - val_boundary_head_loss: 0.0450 - val_classification_head_accuracy: 0.9872 - val_classification_head_loss: 0.0278 - val_loss: 0.0729
# Epoch 32/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0666 - classification_head_accuracy: 0.9851 - classification_head_loss: 0.0395 - loss: 0.1061 - val_boundary_head_loss: 0.0606 - val_classification_head_accuracy: 0.9909 - val_classification_head_loss: 0.0280 - val_loss: 0.0886
# Epoch 33/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0818 - classification_head_accuracy: 0.9840 - classification_head_loss: 0.0462 - loss: 0.1280 - val_boundary_head_loss: 0.0411 - val_classification_head_accuracy: 0.9909 - val_classification_head_loss: 0.0240 - val_loss: 0.0651
# Epoch 34/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0642 - classification_head_accuracy: 0.9852 - classification_head_loss: 0.0375 - loss: 0.1018 - val_boundary_head_loss: 0.0705 - val_classification_head_accuracy: 0.9875 - val_classification_head_loss: 0.0351 - val_loss: 0.1056
# Epoch 35/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0605 - classification_head_accuracy: 0.9881 - classification_head_loss: 0.0321 - loss: 0.0925 - val_boundary_head_loss: 0.0430 - val_classification_head_accuracy: 0.9913 - val_classification_head_loss: 0.0266 - val_loss: 0.0697
# Epoch 36/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0631 - classification_head_accuracy: 0.9886 - classification_head_loss: 0.0310 - loss: 0.0940 - val_boundary_head_loss: 0.0498 - val_classification_head_accuracy: 0.9918 - val_classification_head_loss: 0.0243 - val_loss: 0.0742
# Epoch 37/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0605 - classification_head_accuracy: 0.9863 - classification_head_loss: 0.0441 - loss: 0.1046 - val_boundary_head_loss: 0.1021 - val_classification_head_accuracy: 0.9841 - val_classification_head_loss: 0.0396 - val_loss: 0.1417
# Epoch 38/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0666 - classification_head_accuracy: 0.9854 - classification_head_loss: 0.0399 - loss: 0.1065 - val_boundary_head_loss: 0.0457 - val_classification_head_accuracy: 0.9884 - val_classification_head_loss: 0.0296 - val_loss: 0.0752
# Epoch 39/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0537 - classification_head_accuracy: 0.9872 - classification_head_loss: 0.0345 - loss: 0.0881 - val_boundary_head_loss: 0.0446 - val_classification_head_accuracy: 0.9915 - val_classification_head_loss: 0.0264 - val_loss: 0.0710
# Epoch 40/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0649 - classification_head_accuracy: 0.9859 - classification_head_loss: 0.0385 - loss: 0.1035 - val_boundary_head_loss: 0.0485 - val_classification_head_accuracy: 0.9873 - val_classification_head_loss: 0.0321 - val_loss: 0.0806
# Epoch 41/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0642 - classification_head_accuracy: 0.9868 - classification_head_loss: 0.0334 - loss: 0.0976 - val_boundary_head_loss: 0.0474 - val_classification_head_accuracy: 0.9909 - val_classification_head_loss: 0.0265 - val_loss: 0.0740
# Epoch 42/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0526 - classification_head_accuracy: 0.9887 - classification_head_loss: 0.0310 - loss: 0.0836 - val_boundary_head_loss: 0.0385 - val_classification_head_accuracy: 0.9917 - val_classification_head_loss: 0.0238 - val_loss: 0.0623
# Epoch 43/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - boundary_head_loss: 0.0576 - classification_head_accuracy: 0.9864 - classification_head_loss: 0.0359 - loss: 0.0934 - val_boundary_head_loss: 0.0694 - val_classification_head_accuracy: 0.9906 - val_classification_head_loss: 0.0282 - val_loss: 0.0976
# Epoch 44/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0581 - classification_head_accuracy: 0.9887 - classification_head_loss: 0.0324 - loss: 0.0905 - val_boundary_head_loss: 0.0519 - val_classification_head_accuracy: 0.9889 - val_classification_head_loss: 0.0321 - val_loss: 0.0840
# Epoch 45/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0538 - classification_head_accuracy: 0.9879 - classification_head_loss: 0.0345 - loss: 0.0883 - val_boundary_head_loss: 0.1091 - val_classification_head_accuracy: 0.9832 - val_classification_head_loss: 0.0439 - val_loss: 0.1530
# Epoch 46/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0663 - classification_head_accuracy: 0.9860 - classification_head_loss: 0.0382 - loss: 0.1046 - val_boundary_head_loss: 0.0661 - val_classification_head_accuracy: 0.9861 - val_classification_head_loss: 0.0396 - val_loss: 0.1057
# Epoch 47/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0544 - classification_head_accuracy: 0.9878 - classification_head_loss: 0.0325 - loss: 0.0869 - val_boundary_head_loss: 0.0461 - val_classification_head_accuracy: 0.9906 - val_classification_head_loss: 0.0250 - val_loss: 0.0710
# Epoch 48/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - boundary_head_loss: 0.0562 - classification_head_accuracy: 0.9877 - classification_head_loss: 0.0352 - loss: 0.0914 - val_boundary_head_loss: 0.0432 - val_classification_head_accuracy: 0.9918 - val_classification_head_loss: 0.0263 - val_loss: 0.0696
# Epoch 49/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - boundary_head_loss: 0.0559 - classification_head_accuracy: 0.9890 - classification_head_loss: 0.0299 - loss: 0.0858 - val_boundary_head_loss: 0.0459 - val_classification_head_accuracy: 0.9915 - val_classification_head_loss: 0.0256 - val_loss: 0.0714
# Epoch 50/50
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - boundary_head_loss: 0.0491 - classification_head_accuracy: 0.9889 - classification_head_loss: 0.0296 - loss: 0.0788 - val_boundary_head_loss: 0.0415 - val_classification_head_accuracy: 0.9923 - val_classification_head_loss: 0.0247 - val_loss: 0.0662
# 1794/1794 ━━━━━━━━━━━━━━━━━━━━ 2s 878us/step
# 769/769 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step
# Classification - TRAIN: Acc=0.992, F1=0.990
# Classification - TEST:  Acc=0.992,  F1=0.991

# %%
y_bound_train_flat = y_bound_train.reshape(-1)
y_bound_pred_train_flat = y_bound_pred_train.reshape(-1)

r2_bound_train = r2_score(y_bound_train_flat, y_bound_pred_train_flat)

y_bound_test_flat = y_bound_test.reshape(-1)
y_bound_pred_test_flat = y_bound_pred_test.reshape(-1)
r2_bound_test  = r2_score(y_bound_test_flat, y_bound_pred_test_flat)
print(f"Boundary R² - TRAIN: {r2_bound_train:.4f}, TEST: {r2_bound_test:.4f}")
# Out:
# Boundary R² - TRAIN: 0.9968, TEST: 0.9963

# %%
for _ in range(3):
    idx = random.randint(0, len(id_test)-1)
    true_label = y_class_test[idx]
    pred_prob  = y_class_pred_test[idx][0]
    pred_label = y_class_bin_test[idx]

    print(f"Sample {idx}: True label={true_label} / Pred prob={pred_prob:.3f} / Pred label={pred_label}")

idx = random.randint(0, len(id_test)-1)
bound_true = y_bound_test[idx,:].reshape(-1,2)
bound_pred = y_bound_pred_test[idx,:].reshape(-1,2)

plt.figure(figsize=(10,8))
psi_2d = DB_psi_pixel_test_ConvNet[id_test[idx], :, :]
plt.contour(RR_pixels, ZZ_pixels, psi_2d, 40)
plt.colorbar(label="Poloidal Flux")
plt.plot(bound_true[:,0], bound_true[:,1], 'b--', label="True LCFS")
plt.plot(bound_pred[:,0], bound_pred[:,1], 'g-', markersize=2, label="Pred LCFS")
plt.legend(fontsize=18)
plt.axis('equal')
plt.show()
# Out:
# Sample 1136: True label=0.0 / Pred prob=0.000 / Pred label=0
# Sample 821: True label=1.0 / Pred prob=1.000 / Pred label=1
# Sample 23043: True label=0.0 / Pred prob=0.000 / Pred label=0

# %%
DB_meas_Bpickup_test_ConvNet[0,:].shape
# Out:
# (187,)

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot loss vs epochs
plt.figure(figsize=(8, 5))
plt.semilogy(train_loss, label='Training Loss')
plt.semilogy(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
def compute_GS_operator(psi, RR, ZZ):
    """
    psi shape: (batch, nR, nZ)
    RR, ZZ shape: (nR, nZ) - same for all batch
    Returns: gs_op shape (batch, nR, nZ)
    """
    # naive center-diff. ignoring edges
    # We'll do it in numpy for clarity; for a TF-based approach, we could use tf.nn.conv2d
    
    # We assume psi, RR, ZZ are np arrays for the moment (custom loop).
    # If you want it purely in TF, you'll define a tf function using convolutions.
    
    batch_size = psi.shape[0]
    nR, nZ = psi.shape[1], psi.shape[2]
    gs_op = np.zeros_like(psi)
    
    dR = RR[1,0] - RR[0,0]
    dZ = ZZ[0,1] - ZZ[0,0] if nZ>1 else 1e-3  # you must adapt if your grid is different

    for b in range(batch_size):
        psi_b = psi[b,:,:]
        # Laplacian
        lap = (
            np.roll(psi_b, 1, axis=0) - 2*psi_b + np.roll(psi_b, -1, axis=0)
        )/(dR**2) + (
            np.roll(psi_b, 1, axis=1) - 2*psi_b + np.roll(psi_b, -1, axis=1)
        )/(dZ**2)

        # - (1/R)* d(psi)/dR
        # R is function of row index => R[i,:]
        R_1d = RR[:,0]  # shape (nR,)
        dpsi_dR = (
            np.roll(psi_b, -1, axis=0) - np.roll(psi_b, 1, axis=0)
        )/(2*dR)
        
        # broadcast R to shape (nR, nZ)
        R_2d = np.tile(R_1d.reshape(-1,1), (1,nZ))
        out = lap - (1.0/R_2d)*dpsi_dR
        gs_op[b,:,:] = out

    return gs_op
